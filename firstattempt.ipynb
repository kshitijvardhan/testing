# %%
import pandas as pd
import os

# %%
reviews=pd.read_csv('cps3.csv')

# %%
reviews.head()
# Out:
#    Unnamed: 0  trt  age  educ  black  hisp  marr  nodeg      re74      re75  \
# 0           1    0   30    12      0     0     1      0  20166.73  18347.23
# 1           2    0   26    12      0     0     1      0  25862.32  17806.55
# 2           3    0   25    16      0     0     1      0  25862.32  15316.21
# 3           4    0   42    11      0     0     1      1  21787.05  14265.29
# 4           5    0   25     9      1     0     1      1  14829.69  13776.53
#
#        re78
# 0  25564.67
# 1  25564.67
# 2  25564.67
# 3  15491.01
# 4      0.00

# %%
reviews.tail()
# Out:
#      Unnamed: 0  trt  age  educ  black  hisp  marr  nodeg  re74  re75  \
# 424         425    0   18    11      0     0     0      1   0.0   0.0
# 425         426    0   24     1      0     1     1      1   0.0   0.0
# 426         427    0   21    18      0     0     0      0   0.0   0.0
# 427         428    0   32     5      1     0     1      1   0.0   0.0
# 428         429    0   16     9      0     0     0      1   0.0   0.0
#
#            re78
# 424  10150.5000
# 425  19464.6100
# 426      0.0000
# 427    187.6713
# 428   1495.4590

# %%
reviews.loc[0:4]
# Out:
#    Unnamed: 0  trt  age  educ  black  hisp  marr  nodeg      re74      re75  \
# 0           1    0   30    12      0     0     1      0  20166.73  18347.23
# 1           2    0   26    12      0     0     1      0  25862.32  17806.55
# 2           3    0   25    16      0     0     1      0  25862.32  15316.21
# 3           4    0   42    11      0     0     1      1  21787.05  14265.29
# 4           5    0   25     9      1     0     1      1  14829.69  13776.53
#
#        re78
# 0  25564.67
# 1  25564.67
# 2  25564.67
# 3  15491.01
# 4      0.00

# %%
reviews.rename_axis("row",axis='rows').rename_axis("column",axis='columns')
# Out:
# column  Unnamed: 0  trt  age  educ  black  hisp  marr  nodeg      re74  \
# row
# 0                1    0   30    12      0     0     1      0  20166.73
# 1                2    0   26    12      0     0     1      0  25862.32
# 2                3    0   25    16      0     0     1      0  25862.32
# 3                4    0   42    11      0     0     1      1  21787.05
# 4                5    0   25     9      1     0     1      1  14829.69
# ..             ...  ...  ...   ...    ...   ...   ...    ...       ...
# 424            425    0   18    11      0     0     0      1      0.00
# 425            426    0   24     1      0     1     1      1      0.00
# 426            427    0   21    18      0     0     0      0      0.00
# 427            428    0   32     5      1     0     1      1      0.00
# 428            429    0   16     9      0     0     0      1      0.00
#
# column      re75        re78
# row
# 0       18347.23  25564.6700
# 1       17806.55  25564.6700
# ...

# %%
reviews.sort_values('age')
# Out:
#      Unnamed: 0  trt  age  educ  black  hisp  marr  nodeg       re74  \
# 428         429    0   16     9      0     0     0      1     0.0000
# 368         369    0   16     8      0     0     0      1     0.0000
# 401         402    0   16     8      0     0     0      1     0.0000
# 251         252    0   16     7      0     0     0      1   658.3136
# 250         251    0   16     9      0     0     0      1     0.0000
# ..          ...  ...  ...   ...    ...   ...   ...    ...        ...
# 359         360    0   55     6      0     0     1      1   111.6782
# 403         404    0   55     7      0     0     0      1     0.0000
# 386         387    0   55     4      1     0     0      1     0.0000
# 345         346    0   55     3      0     0     0      1  1208.8680
# 420         421    0   55     8      0     0     1      1     0.0000
#
#          re75      re78
# 428    0.0000  1495.459
# 368    0.0000     0.000
# 401    0.0000     0.000
# 251  479.8065  6210.885
# ...

# %%
reviews.groupby('age').educ.agg(['max','min'])
# Out:
#      max  min
# age
# 16    10    6
# 17    11    5
# 18    12    7
# 19    13    3
# 20    14    7
# 21    18    8
# 22    16    8
# 23    17    8
# 24    15    1
# 25    16    5
# 26    14    5
# 27    15    4
# 28    13    5
# 29    13    6
# 30    17    7
# 31    16    2
# 32    16    4
# 33    12    8
# 34    12    8
# 35    13    7
# 36    18    1
# 37    14    7
# 38    12    8
# 39    12    2
# 40    16    3
# 41    15    5
# 42    16    0
# 43    12    6
# 44    13   13
# 45    12    8
# 46    11    7
# 47    11    3
# 48    14    7
# 49    14    8
# 50    12    0
# 51    12    4
# 52    12    0
# 53    12   10
# 54    12   12
# 55     8    3

# %%
reviews.age.describe()
# Out:
# count    429.000000
# mean      28.030303
# std       10.786653
# min       16.000000
# 25%       19.000000
# 50%       25.000000
# 75%       35.000000
# max       55.000000
# Name: age, dtype: float64
